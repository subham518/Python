# %%
import pandas as pd

# %%
df_music = pd.read_csv('music.csv')
df_music
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
df_X = df_music.drop(columns=['genre'])

# %%
Y = df_music['genre']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(df_X, Y)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict([[21, 1], [22, 0]])
# Out:
# C:\Users\monis\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array(['HipHop', 'Dance'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
train_X, test_X, train_Y, test_Y = train_test_split(df_X, Y, test_size = 0.2)

# %%
model.fit(train_X, train_Y)
prediction = model.predict(test_X)

# %%
score = accuracy_score(test_Y, prediction)

# %%
score
# Out:
# 1.0

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
# saving and loading models
import joblib

music_data = pd.read_csv('music.csv')
X= music_data.drop(columns=['genre'])
Y = music_data['genre']

model = DecisionTreeClassifier()
model.fit(X, Y)

joblib.dump(model, 'music-recommender.joblib')

# predictions = model.predict([[21, 1]])
# Out:
# ['music-recommender.joblib']

# %%
# now no need to run model every time
sto_model = joblib.load('music-recommender.joblib')

# %%
predictions = sto_model.predict([[21,1]])
predictions
