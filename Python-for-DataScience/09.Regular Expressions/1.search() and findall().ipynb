# %% [markdown]
# # The re module

# %%
import re

# %% [markdown]
# ## re.search()

# %%
text="""Hello World.
I love Python!!!!!
My first lucky number is 987-654-321
My second lucky number is 876-543-210
My third lucky number is 765-432-100
My fourth lucky number is 123-456-123-123-456
"""

# %%
# return the first match (digit)
re.search(r'\d',text)
# Out:
# <re.Match object; span=(57, 58), match='9'>

# %%
# flags
re.search(r'^hello', text, flags=re.I) # insensitive flag
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %% [markdown]
# ## re.findall()

# %%
# return all the matches
re.findall(r'\d', text)
# Out:
# ['9',
#  '8',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '8',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '0',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '0',
#  '0',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '1',
#  '2',
#  '3',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6']
